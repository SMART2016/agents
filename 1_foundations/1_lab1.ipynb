# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

#from openai import OpenAI
import ollama

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(
    base_url="http://localhost:11434/",
    api_key="ollama"  # Ollama doesn't need a key, but OpenAI client requires something
)

# List available models
print("Available models:")
models = openai.models.list()
for model in models:
    print(f"  {model.id}")
# Out:
# Available models:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[23], line 13
#      11 # List available models
#      12 print("Available models:")
# ---> 13 models = openai.models.list()
#      14 for model in models:
#      15     print(f"  {model.id}")
#
# File ~/work/projects/agents/.venv/lib/python3.12/site-packages/openai/resources/models.py:91, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      77 def list(
#      78     self,
#      79     *,
#    (...)     85     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      86 ) -> SyncPage[Model]:
#      87     """
#      88     Lists the currently available models, and provides basic information about each
#      89     one such as the owner and availability.
#      90     """
# ---> 91     return self._get_api_list(
#      92         "/models",
#      93         page=SyncPage[Model],
#      94         options=make_request_options(
#      95             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      96         ),
#      97         model=Model,
#      98     )
#
# File ~/work/projects/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1298, in SyncAPIClient.get_api_list(self, path, model, page, body, options, method)
#    1287 def get_api_list(
#    1288     self,
#    1289     path: str,
#    (...)   1295     method: str = "get",
#    1296 ) -> SyncPageT:
#    1297     opts = FinalRequestOptions.construct(method=method, url=path, json_data=body, **options)
# -> 1298     return self._request_api_list(model, page, opts)
#
# File ~/work/projects/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1149, in SyncAPIClient._request_api_list(self, model, page, options)
#    1145     return resp
#    1147 options.post_parser = _parser
# -> 1149 return self.request(page, options, stream=False)
#
# File ~/work/projects/agents/.venv/lib/python3.12/site-packages/openai/_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1034             err.response.read()
#    1036         log.debug("Re-raising status error")
# -> 1037         raise self._make_status_error_from_response(err.response) from None
#    1039     break
#    1041 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: 404 page not found

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
# response = openai.chat.completions.create(
#     model="llama3.2",  # or "mistral", "llama2", etc.
#     messages=messages
# )

response = ollama.chat(
    model='llama3.2',
    messages=messages
)

print(response['message']['content'])
# Out:
# 2 + 2 = 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano
response = ollama.chat(
    model='deepseek-coder-v2',
    messages=messages
)

question = response['message']['content']

print(question)
# Out:
#  What is the volume of a triangular prism if its base area is 20 square units and its height is 15 units?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = ollama.chat(
    model="deepseek-coder-v2",
    messages=messages
)

answer = response['message']['content']
print(answer)
# Out:
#  To find the volume of a triangular prism, we use the formula for the volume of a prism, which is given by:
#
# \[ V = \text{base area} \times \text{height} \]
#
# We are provided with the following information:
# - The base area of the triangular prism is 20 square units.
# - The height of the triangular prism is 15 units.
#
# Substituting these values into the formula, we get:
#
# \[ V = 20 \, \text{square units} \times 15 \, \text{units} \]
#
# Now, let's perform the multiplication:
#
# \[ V = 20 \times 15 \]
#
# Calculating this, we find:
#
# \[ V = 300 \]
#
# Therefore, the volume of the triangular prism is:
#
# \[ \boxed{300} \]

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
#  To find the volume of a triangular prism, we use the formula for the volume of a prism, which is given by:
#
# \[ V = \text{base area} \times \text{height} \]
#
# We are provided with the following information:
# - The base area of the triangular prism is 20 square units.
# - The height of the triangular prism is 15 units.
#
# Substituting these values into the formula, we get:
#
# \[ V = 20 \, \text{square units} \times 15 \, \text{units} \]
#
# Now, let's perform the multiplication:
#
# \[ V = 20 \times 15 \]
#
# Calculating this, we find:
#
# \[ V = 300 \]
#
# Therefore, the volume of the triangular prism is:
#
# \[ \boxed{300} \]

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "pick a business area that might be worth exploring for an Agentic AI opportunity in Identity and access management domain."}]

# Then make the first call:

response = ollama.chat(
    model="deepseek-coder-v2",
    messages=messages
)

# Then read the business idea:

business_idea = response['message']['content']
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
#  Exploring the realm of identity and access management (IAM) through the lens of agentic AI presents several intriguing opportunities for innovation and growth within the technology sector. IAM is critical to maintaining robust security practices, managing user identities across various digital platforms, and ensuring that only authorized individuals have access to sensitive information or systems. Agentic AI, with its focus on creating intelligent agents that can learn from their environment and make autonomous decisions, could potentially revolutionize how businesses manage and secure their identity management frameworks.
#
# ### Potential Opportunities for Agentic AI in IAM:
#
# 1. **Adaptive Authentication**: Traditional authentication methods often rely on static passwords or single-factor verification, which are increasingly vulnerable to attacks. Agentic AI can be used to develop adaptive authentication systems that use machine learning algorithms to predict user behavior and adjust the level of security required based on real-time risk assessments. For example, an agent could analyze a user's login patterns and adjust from requiring only a password to needing additional factors such as biometrics or one-time codes if there’s suspicion of unusual activity.
#
# 2. **User Behavior Analytics**: Agentic AI can monitor user behavior across applications and systems in real-time. By analyzing the way users interact with digital platforms, these agents can detect anomalous behaviors that might indicate a potential security breach or unauthorized access attempts. This proactive approach to monitoring can significantly enhance the overall security posture of an organization without relying solely on reactive measures.
#
# 3. **Automated Identity Provisioning and Decommissioning**: Implementing new users into systems manually is time-consuming and prone to errors. Agentic AI can automate this process based on predefined policies, ensuring that new hires are provisioned with the appropriate level of access as soon as they start work, while also automating the removal or modification of access rights for terminated employees according to strict timelines set by compliance regulations.
#
# 4. **Risk-Based Access Control**: Traditional IAM often grants users broad and equal access across all resources within an organization, which can be inefficient and expose sensitive data unnecessarily. Agentic AI could implement a risk-based approach where the level of access granted is determined not only by who a user is but also by what they need to do (risk profile). For instance, someone handling high-value transactions might have different access controls compared to a low-level administrative assistant.
#
# 5. **Enhanced User Experience**: By automating routine identity management tasks and reducing the burden on IT departments for repetitive security checks, agentic AI can significantly enhance the user experience by making digital interactions smoother and more intuitive. This could include self-service password resets or streamlined multi-factor authentication processes that are easier to manage than manual procedures.
#
# 6. **Compliance and Governance**: Managing compliance with various regulations such as GDPR, HIPAA, or others can be complex for large organizations. Agentic AI can help automate the process of assessing and maintaining compliance by continuously monitoring access policies against regulatory standards. This not only helps in avoiding penalties but also ensures that the organization is always aligned with legal requirements.
#
# ### Conclusion:
# Exploring these opportunities would require a deep understanding of both IAM principles and how agentic AI technologies function, including machine learning, natural language processing, and predictive analytics. By integrating agentic AI into identity management solutions, businesses can not only enhance security but also improve operational efficiency and user satisfaction across their digital infrastructures.

# %%
messages = [{"role": "user", "content": "Based on one of the ideas from " + business_idea + ", please propose a pain point that might be worth exploring for an Agentic AI solution."}]

response = ollama.chat(
    model="deepseek-coder-v2",
    messages=messages
)

# Then read the business idea:

paint_point = response['message']['content']
print(paint_point)
# Out:
#  ### Pain Point to Explore: Overwhelming User Onboarding and Offboarding Process in Large Enterprises
#
# #### Description of the Problem:
# In large enterprises, managing onboarding and offboarding processes for new employees or termination of existing ones can be a cumbersome task involving multiple departments and manual intervention across various systems. This process often involves significant administrative effort to update user roles, permissions, access levels, and remove access from terminated employees' accounts in a timely manner according to compliance regulations. These tasks are not only time-consuming but also prone to errors due to the complexity of managing diverse sets of policies and accessing multiple databases across different systems like HRIS (Human Resource Information Systems), ERP (Enterprise Resource Planning) systems, and IAM platforms.
#
# #### How Agentic AI Can Address This Pain Point:
# 1. **Automated Onboarding**: Utilizing agentic AI, businesses can streamline the onboarding process by automatically provisioning new users with appropriate access levels based on job roles and departmental requirements specified during the hiring phase. The AI system could integrate with HR systems to fetch necessary information about the employee's role and responsibilities, ensuring that all relevant permissions are granted swiftly upon employment.
#
# 2. **Automated Offboarding**: Agentic AI can automate the offboarding process by automatically decommissioning user accounts as soon as an individual leaves the company according to legal timelines. This involves removing access rights promptly after a termination notice is received and terminating any active sessions or tokens associated with the terminated employee's account across all platforms where they had access.
#
# 3. **Real-Time Compliance Monitoring**: AI agents can be programmed to monitor compliance throughout the duration of employment, including tracking changes in job roles that might affect access privileges. This proactive monitoring ensures continuous adherence to access control policies and any regulatory requirements without manual intervention.
#
# 4. **Enhanced Security Through Automated Risk Assessment**: By analyzing patterns of use and behavior before termination, agentic AI can detect anomalous activity or potential risks associated with an employee's account usage that might indicate unauthorized actions. This enables swift action to secure sensitive information by terminating access immediately upon suspicion of misuse or breach.
#
# 5. **Reduced Administrative Burden on HR and IT**: With automated processes managed by AI, HR and IT departments can significantly reduce the administrative burden associated with managing user identities, allowing them more time for strategic tasks that require human expertise such as talent acquisition and employee development.
#
# #### Conclusion:
# Addressing this pain point through agentic AI could not only improve operational efficiency in large enterprises but also enhance security by ensuring that access controls are updated promptly according to organizational policies and compliance requirements. The integration of machine learning and automated decision-making capabilities within an enterprise setting can lead to a more secure, efficient, and user-friendly identity management system for both employees and administrators.

# %%
messages = [{"role": "user", "content": "Please propose an Agentic AI solution to the pain point: " + paint_point + "."}]

response = ollama.chat(
    model="deepseek-coder-v2",
    messages=messages
)

# Then read the business idea:

solution = response['message']['content']
print(solution)
# Out:
#  ### Proposed Solution: Utilizing Agentic AI in Enterprise User Management
#
# #### Overview:
# In large enterprises where onboarding and offboarding processes are cumbersome and prone to errors due to manual intervention across multiple systems, the integration of Agentic AI can significantly streamline these processes. This solution leverages artificial intelligence to automate and optimize user management tasks such as provisioning new users, decommissioning terminated accounts, monitoring compliance, and enhancing security through automated risk assessment.
#
# #### Key Components:
# 1. **Automated Onboarding:**
#    - **Integration with HR Systems:** Agentic AI will be integrated with the enterprise’s HRIS to extract job role details of new hires at the time of employment. Based on these roles, the AI system automatically configures user accounts with appropriate access levels across various systems including ERP and IAM platforms. This ensures that all necessary permissions are granted immediately upon joining without manual intervention.
#    - **Role-Based Access Provisioning:** The AI will configure each new employee’s account based on their specific role within the organization, ensuring they have only those privileges required for their job functions while preventing unnecessary access to sensitive information or systems.
#
# 2. **Automated Offboarding:**
#    - **Real-Time Exit Management:** When an employee leaves, Agentic AI triggers a swift decommissioning process that immediately revokes all active sessions and deletes the user account from all relevant platforms within legal compliance timelines. This includes terminating access to ERP, CRM, and other enterprise systems where they had permissions.
#    - **Automated Compliance Updates:** The system continuously checks for changes in role assignments or termination notices. It automatically updates access controls according to these events without requiring manual intervention, ensuring ongoing compliance with organizational policies and regulatory requirements.
#
# 3. **Real-Time Risk Assessment:**
#    - **Anomaly Detection:** Agentic AI uses machine learning algorithms to analyze user activity patterns before termination. If it detects any unusual behavior or potential security risks (such as unauthorized access attempts), the system triggers an immediate review by authorized personnel, followed by account deactivation to secure sensitive data.
#    - **Automated Risk Reporting:** The AI can generate automated reports on compliance and risk assessment metrics that help in strategic decision-making related to user management policies and practices.
#
# 4. **Enhanced Security Measures:**
#    - **Proactive Compliance Monitoring:** By continuously monitoring access rights, Agentic AI ensures that all users are compliant with the organization’s security protocols at all times without manual checks. This includes periodic reviews of permissions assigned based on job role changes or performance indicators.
#    - **Quick Response to Threats:** The system is designed to react swiftly to any detected threats, allowing for immediate account termination and potential forensic analysis if necessary, thereby minimizing the risk associated with data breaches due to terminated employees’ access.
#
# 5. **User Experience Improvement:**
#    - **Automated Notifications:** Automated emails or alerts can inform users of their account status changes (e.g., password resets, role updates) via a user-friendly interface that is accessible from any device connected to the enterprise network.
#    - **Self-Service Capabilities:** Employees can access and update personal information through an online portal managed by Agentic AI, reducing administrative load on HR and IT teams.
#
# #### Benefits:
# - **Cost Efficiency:** Reduces manual labor costs associated with managing user accounts across multiple systems manually.
# - **Security:** Enhances security posture by ensuring that access controls are updated in real time according to organizational policies and regulatory requirements.
# - **Compliance:** Ensures compliance with internal policies, legal regulations, and cybersecurity standards through automated monitoring and reporting.
# - **Scalability:** Scales seamlessly with the growth of the organization without additional overhead for manual processes.
# - **User Satisfaction:** Improves user experience by providing timely account provisioning and decommissioning services that are largely automatic.
#
# #### Conclusion:
# The deployment of Agentic AI in large enterprises for managing onboarding and offboarding processes not only simplifies complex administrative tasks but also enhances the overall security and compliance posture of an organization. By automating these manual, error-prone processes with intelligent automation, companies can achieve a more efficient and secure user management framework that benefits both employees and administrators.
